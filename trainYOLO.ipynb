# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/gdrive/MyDrive/pred/data/data
# Out:
# /content/gdrive/MyDrive/pred/data/data

# %%
# !pip install opencv-python-headless torchvision
# Add the correct command to install the YOLO model from Ultralytics if needed
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
DIR = "/content/gdrive/MyDrive/pred/data/data"

# %%
from ultralytics import YOLO
model = YOLO('yolov8l-cls.pt')# Load model
model.train(data=DIR, epochs=80
            , imgsz=[41, 60])
# Out:
# ...
# 100%|██████████| 71.7M/71.7M [00:00<00:00, 78.6MB/s]
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
